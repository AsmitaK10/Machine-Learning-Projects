# %% [markdown]
# ### Import the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Read the data

# %%
df = pd.read_excel('Pistachio_16_Features_Dataset.xlsx')
df
# Out:
#         AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0      63391  1568.4050    390.3396    236.7461        0.7951  284.0984
# 1      68358  1942.1870    410.8594    234.7525        0.8207  295.0188
# 2      73589  1246.5380    452.3630    220.5547        0.8731  306.0987
# 3      71106  1445.2610    429.5291    216.0765        0.8643  300.8903
# 4      80087  1251.5240    469.3783    220.9344        0.8823  319.3273
# ...      ...        ...         ...         ...           ...       ...
# 2143   85983  1157.1160    444.3447    248.8627        0.8284  330.8730
# 2144   85691  2327.3459    439.8794    278.9297        0.7732  330.3107
# 2145  101136  1255.6190    475.2161    271.3299        0.8210  358.8459
# 2146   97409  1195.2150    452.1823    274.5764        0.7945  352.1718
# 2147   78466  2356.9080    445.9131    258.5125        0.8148  316.0791
#
#       SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  COMPACTNESS  \
# ...

# %%
df.columns
# Out:
# Index(['AREA', 'PERIMETER', 'MAJOR_AXIS', 'MINOR_AXIS', 'ECCENTRICITY',
#        'EQDIASQ', 'SOLIDITY', 'CONVEX_AREA', 'EXTENT', 'ASPECT_RATIO',
#        'ROUNDNESS', 'COMPACTNESS', 'SHAPEFACTOR_1', 'SHAPEFACTOR_2',
#        'SHAPEFACTOR_3', 'SHAPEFACTOR_4', 'Class'],
#       dtype='object')

# %% [markdown]
# #### Checking missing & duplicate values

# %%
df.isnull().sum()
# Out:
# AREA             0
# PERIMETER        0
# MAJOR_AXIS       0
# MINOR_AXIS       0
# ECCENTRICITY     0
# EQDIASQ          0
# SOLIDITY         0
# CONVEX_AREA      0
# EXTENT           0
# ASPECT_RATIO     0
# ROUNDNESS        0
# COMPACTNESS      0
# SHAPEFACTOR_1    0
# SHAPEFACTOR_2    0
# SHAPEFACTOR_3    0
# SHAPEFACTOR_4    0
# Class            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Load the data

# %%
#Input data
x = df.drop('Class', axis=1)
#Output data
y = df['Class']

# %%
x
# Out:
#         AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS  ECCENTRICITY   EQDIASQ  \
# 0      63391  1568.4050    390.3396    236.7461        0.7951  284.0984
# 1      68358  1942.1870    410.8594    234.7525        0.8207  295.0188
# 2      73589  1246.5380    452.3630    220.5547        0.8731  306.0987
# 3      71106  1445.2610    429.5291    216.0765        0.8643  300.8903
# 4      80087  1251.5240    469.3783    220.9344        0.8823  319.3273
# ...      ...        ...         ...         ...           ...       ...
# 2143   85983  1157.1160    444.3447    248.8627        0.8284  330.8730
# 2144   85691  2327.3459    439.8794    278.9297        0.7732  330.3107
# 2145  101136  1255.6190    475.2161    271.3299        0.8210  358.8459
# 2146   97409  1195.2150    452.1823    274.5764        0.7945  352.1718
# 2147   78466  2356.9080    445.9131    258.5125        0.8148  316.0791
#
#       SOLIDITY  CONVEX_AREA  EXTENT  ASPECT_RATIO  ROUNDNESS  COMPACTNESS  \
# ...

# %%
df.dtypes
# Out:
# AREA               int64
# PERIMETER        float64
# MAJOR_AXIS       float64
# MINOR_AXIS       float64
# ECCENTRICITY     float64
# EQDIASQ          float64
# SOLIDITY         float64
# CONVEX_AREA        int64
# EXTENT           float64
# ASPECT_RATIO     float64
# ROUNDNESS        float64
# COMPACTNESS      float64
# SHAPEFACTOR_1    float64
# SHAPEFACTOR_2    float64
# SHAPEFACTOR_3    float64
# SHAPEFACTOR_4    float64
# Class             object
# dtype: object

# %% [markdown]
# ### Exploratory Data Analysis

# %%
y.value_counts()
# Out:
# Kirmizi_Pistachio    1232
# Siit_Pistachio        916
# Name: Class, dtype: int64

# %%
sns.countplot(x = df['Class'])
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
one = df.iloc[:, 0:4]
one['Class']=y

two = df.iloc[:, 4:8]
two['Class']=y

three = df.iloc[:, 8:12]
three['Class']=y

four = df.iloc[:, 12:16]
four['Class']=y

# %%
sns.pairplot(one, hue='Class')

# %%
sns.pairplot(two, hue='Class')

# %%
sns.pairplot(three, hue='Class')

# %%
sns.pairplot(four, hue='Class')

# %% [markdown]
# ### Outlier Detection

# %%
plt.figure(figsize=(16,9))
sns.boxplot(data=x)
# Out:
# <AxesSubplot:>

# %%
x.max()
# Out:
# AREA             124008.0000
# PERIMETER          2755.0491
# MAJOR_AXIS          541.9661
# MINOR_AXIS          383.0461
# ECCENTRICITY          0.9460
# EQDIASQ             397.3561
# SOLIDITY              0.9951
# CONVEX_AREA      132478.0000
# EXTENT                0.8204
# ASPECT_RATIO          3.0858
# ROUNDNESS             0.9336
# COMPACTNESS           0.8779
# SHAPEFACTOR_1         0.0131
# SHAPEFACTOR_2         0.0053
# SHAPEFACTOR_3         0.7706
# SHAPEFACTOR_4         0.9990
# dtype: float64

# %%
plt.figure(figsize=(16,9))
sns.boxplot(data= x.drop(['AREA', 'CONVEX_AREA'], axis=1))
# Out:
# <AxesSubplot:>

# %%
from sklearn.ensemble import IsolationForest

# %%
iso = IsolationForest(random_state=0, contamination=0.05)

# %%
clean = iso.fit_predict(x,y)

# %%
clean
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
x_clean = x[clean==1]
x_clean.shape
# Out:
# (2040, 16)

# %%
y_clean = y[clean==1]
y_clean.shape
# Out:
# (2040,)

# %% [markdown]
# ### Resampling the data

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ros = RandomOverSampler(random_state=0)

# %%
x_res, y_res= ros.fit_resample(x_clean, y_clean)

# %%
x_res.shape
# Out:
# (2356, 16)

# %%
sns.countplot(x=y_res)
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
y_res.value_counts()
# Out:
# Kirmizi_Pistachio    1178
# Siit_Pistachio       1178
# Name: Class, dtype: int64

# %% [markdown]
# ### Feature Selection

# %%
from sklearn.feature_selection import SelectKBest, chi2

# %%
skf = SelectKBest(k=10, score_func=chi2)

# %%
skf.fit(x,y)
# Out:
# SelectKBest(score_func=<function chi2 at 0x000001BFE6A7E700>)

# %%
skf.get_support()
# Out:
# array([ True,  True,  True,  True, False,  True, False,  True, False,
#         True,  True,  True, False, False,  True, False])

# %%
x = x_res.iloc[:, skf.get_support()]

# %%
x
# Out:
#        AREA  PERIMETER  MAJOR_AXIS  MINOR_AXIS   EQDIASQ  CONVEX_AREA  \
# 0     63391  1568.4050    390.3396    236.7461  284.0984        73160
# 1     68358  1942.1870    410.8594    234.7525  295.0188        77991
# 2     73589  1246.5380    452.3630    220.5547  306.0987        80234
# 3     71106  1445.2610    429.5291    216.0765  300.8903        74153
# 4     80087  1251.5240    469.3783    220.9344  319.3273        82929
# ...     ...        ...         ...         ...       ...          ...
# 2351  73212  1276.6710    410.6384    250.3580  305.3136        81705
# 2352  80701  1240.0820    417.4089    250.9569  320.5491        84184
# 2353  91919  1485.9790    501.6235    235.8714  342.1036        95553
# 2354  97269  2058.1951    473.8028    271.5347  351.9186       103556
# 2355  97139  1206.2660    451.1662    275.2557  351.6834        98014
#
#       ASPECT_RATIO  ROUNDNESS  COMPACTNESS  SHAPEFACTOR_3
# 0           1.6488     0.3238       0.7278         0.5297
# ...

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
x_scaled = scaler.fit_transform(x)

# %%
pd.DataFrame(x_scaled).describe()
# Out:
#                  0            1            2            3            4  \
# count  2356.000000  2356.000000  2356.000000  2356.000000  2356.000000
# mean      0.503690     0.263526     0.513598     0.521469     0.553266
# std       0.169807     0.200205     0.156538     0.181667     0.167412
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.387295     0.129883     0.408911     0.388963     0.443118
# 50%       0.504416     0.178056     0.521223     0.517460     0.560152
# 75%       0.626731     0.348199     0.621179     0.650643     0.676258
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                  5            6            7            8            9
# count  2356.000000  2356.000000  2356.000000  2356.000000  2356.000000
# mean      0.541743     0.394490     0.592507     0.468716     0.431911
# std       0.170352     0.163557     0.267579     0.166847     0.166088
# ...

# %% [markdown]
# ### Cross validation

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x_scaled, y_res, random_state=0, stratify=y_res)

# %%
x_train.shape
# Out:
# (1767, 10)

# %%
x_test.shape
# Out:
# (589, 10)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Decision Tree Classifier

# %% [markdown]
# #### Hyperparameter tuning

# %%
params = {
    'criterion' : ['gini', 'entropy', 'log_loss'],
    'splitter' : ['best', 'random'],
    'random_state' : [0,1,2,3,4]
}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

# %%
grid = GridSearchCV(DecisionTreeClassifier(),
                   param_grid=params,cv=5)

# %%
grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'random_state': [0, 1, 2, 3, 4],
#                          'splitter': ['best', 'random']})

# %%
grid.best_estimator_
# Out:
# DecisionTreeClassifier(random_state=2)

# %% [markdown]
# #### Build the model

# %%
dt = grid.best_estimator_

# %%
y_pred_dt = dt.predict(x_test)

# %% [markdown]
# #### Performance Analysis

# %%
from sklearn.metrics import classification_report, accuracy_score
from sklearn.metrics import ConfusionMatrixDisplay

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_dt)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
print(classification_report(y_test, y_pred_dt))
# Out:
#                    precision    recall  f1-score   support
#
# Kirmizi_Pistachio       0.87      0.82      0.85       295
#    Siit_Pistachio       0.83      0.88      0.86       294
#
#          accuracy                           0.85       589
#         macro avg       0.85      0.85      0.85       589
#      weighted avg       0.85      0.85      0.85       589

# %%
print('Accuracy score:', accuracy_score(y_test, y_pred_dt)*100)
# Out:
# Accuracy score: 85.22920203735144

# %% [markdown]
# #### Plot the tree

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(20,20))
plot_tree(dt, fontsize=8, filled=True, rounded=True,
         feature_names=x.columns, class_names=['K','S']);

# %% [markdown]
# ### Random Forest Classifier

# %% [markdown]
# #### Hyperparameter Tuning

# %%
params = {
    'criterion' : ['gini', 'entropy', 'log_loss'],
    'n_estimators' : range(10,100,5),
    'random_state' : [0,1,2,3,4]
}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
grid = GridSearchCV(RandomForestClassifier(),
                   param_grid=params,cv=5)

# %%
grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'n_estimators': range(10, 100, 5),
#                          'random_state': [0, 1, 2, 3, 4]})

# %%
grid.best_estimator_
# Out:
# RandomForestClassifier(n_estimators=70, random_state=0)

# %% [markdown]
# #### Build the model

# %%
rf = grid.best_estimator_

# %%
y_pred_rf = rf.predict(x_test)

# %% [markdown]
# #### Performance Analysis

# %%
from sklearn.metrics import classification_report, accuracy_score
from sklearn.metrics import ConfusionMatrixDisplay

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_rf)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
print(classification_report(y_test, y_pred_rf))
# Out:
#                    precision    recall  f1-score   support
#
# Kirmizi_Pistachio       0.93      0.86      0.89       295
#    Siit_Pistachio       0.87      0.94      0.90       294
#
#          accuracy                           0.90       589
#         macro avg       0.90      0.90      0.90       589
#      weighted avg       0.90      0.90      0.90       589

# %%
print('Accuracy score:', accuracy_score(y_test, y_pred_rf)*100)
# Out:
# Accuracy score: 89.64346349745331

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# #### Hyperparameter Tuning

# %%
params = {'C' : [0.1, 1, 10]}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression

# %%
grid = GridSearchCV(LogisticRegression(),
                   param_grid=params,cv=5)

# %%
grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [0.1, 1, 10]})

# %%
grid.best_estimator_
# Out:
# LogisticRegression(C=1)

# %% [markdown]
# #### Build the model

# %%
lr = grid.best_estimator_

# %%
y_pred_lr = lr.predict(x_test)

# %% [markdown]
# #### Performance Analysis

# %%
from sklearn.metrics import classification_report, accuracy_score
from sklearn.metrics import ConfusionMatrixDisplay

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_lr)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
print(classification_report(y_test, y_pred_lr))
# Out:
#                    precision    recall  f1-score   support
#
# Kirmizi_Pistachio       0.90      0.87      0.88       295
#    Siit_Pistachio       0.87      0.90      0.89       294
#
#          accuracy                           0.88       589
#         macro avg       0.88      0.88      0.88       589
#      weighted avg       0.88      0.88      0.88       589

# %%
print('Accuracy score:', accuracy_score(y_test, y_pred_lr)*100)
# Out:
# Accuracy score: 88.45500848896435

# %% [markdown]
# ### K-Nearest Neighbour (KNN)

# %% [markdown]
# #### Hyperparameter Tuning

# %%
params = {'n_neighbors': range(1,100,2),
           'weights': ['uniform', 'distance'],
           'p': [1, 2]}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

# %%
grid = GridSearchCV(KNeighborsClassifier(),
                   param_grid=params,cv=5)

# %%
grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': range(1, 100, 2), 'p': [1, 2],
#                          'weights': ['uniform', 'distance']})

# %%
grid.best_estimator_
# Out:
# KNeighborsClassifier(n_neighbors=51, p=1, weights='distance')

# %% [markdown]
# #### Build the model

# %%
knn = grid.best_estimator_

# %%
y_pred_knn = knn.predict(x_test)

# %% [markdown]
# #### Performance Analysis

# %%
from sklearn.metrics import classification_report, accuracy_score
from sklearn.metrics import ConfusionMatrixDisplay

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_knn)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
print(classification_report(y_test, y_pred_knn))
# Out:
#                    precision    recall  f1-score   support
#
# Kirmizi_Pistachio       0.95      0.87      0.91       295
#    Siit_Pistachio       0.88      0.95      0.91       294
#
#          accuracy                           0.91       589
#         macro avg       0.91      0.91      0.91       589
#      weighted avg       0.91      0.91      0.91       589

# %%
print('Accuracy score:', accuracy_score(y_test, y_pred_knn)*100)
# Out:
# Accuracy score: 91.00169779286928

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

# %%
gnb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# #### Build the model

# %%
y_pred_gnb = gnb.predict(x_test)

# %% [markdown]
# #### Performance Analysis

# %%
from sklearn.metrics import classification_report, accuracy_score
from sklearn.metrics import ConfusionMatrixDisplay

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_gnb)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
print(classification_report(y_test, y_pred_gnb))
# Out:
#                    precision    recall  f1-score   support
#
# Kirmizi_Pistachio       0.89      0.87      0.88       295
#    Siit_Pistachio       0.87      0.89      0.88       294
#
#          accuracy                           0.88       589
#         macro avg       0.88      0.88      0.88       589
#      weighted avg       0.88      0.88      0.88       589

# %%
print('Accuracy score:', accuracy_score(y_test, y_pred_gnb)*100)
# Out:
# Accuracy score: 87.77589134125637

# %% [markdown]
# ### Support Vector Machines (SVM)

# %% [markdown]
# #### Hyperparameter Tuning

# %%
params = {'C': [0.1, 1, 10], 
           'kernel': ['linear', 'rbf', 'poly', 'sigmoid']}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

# %%
grid = GridSearchCV(SVC(),
                    param_grid=params,cv=5)

# %%
grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']})

# %%
grid.best_estimator_
# Out:
# SVC(C=0.1, kernel='poly')

# %% [markdown]
# #### Build the model

# %%
svc = grid.best_estimator_

# %%
y_pred_svc = svc.predict(x_test)

# %% [markdown]
# #### Performance Analysis

# %%
from sklearn.metrics import classification_report, accuracy_score
from sklearn.metrics import ConfusionMatrixDisplay

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_svc)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
print(classification_report(y_test, y_pred_svc))
# Out:
#                    precision    recall  f1-score   support
#
# Kirmizi_Pistachio       0.89      0.88      0.89       295
#    Siit_Pistachio       0.89      0.89      0.89       294
#
#          accuracy                           0.89       589
#         macro avg       0.89      0.89      0.89       589
#      weighted avg       0.89      0.89      0.89       589

# %%
print('Accuracy score:', accuracy_score(y_test, y_pred_svc)*100)
# Out:
# Accuracy score: 88.96434634974533

# %% [markdown]
# ### Artificial Neural Network (ANN)

# %%
params = {'activation' : ['logistic','tanh','relu','identity'],
          'hidden_layer_sizes' : [(50,),(100,),(150,),(200,)],
          'max_iter' : [100],
            'learning_rate': ['constant', 'invscaling', 'adaptive'],
          'random_state' : [0]}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neural_network import MLPClassifier

# %%
grid = GridSearchCV(MLPClassifier(),
                    param_grid=params,cv=5)

# %%
grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=MLPClassifier(),
#              param_grid={'activation': ['logistic', 'tanh', 'relu', 'identity'],
#                          'hidden_layer_sizes': [(50,), (100,), (150,), (200,)],
#                          'learning_rate': ['constant', 'invscaling',
#                                            'adaptive'],
#                          'max_iter': [100], 'random_state': [0]})

# %%
grid.best_estimator_
# Out:
# MLPClassifier(activation='logistic', hidden_layer_sizes=(150,), max_iter=100,
#               random_state=0)

# %% [markdown]
# #### Build the model

# %%
mlp = grid.best_estimator_

# %%
y_pred_mlp = mlp.predict(x_test)

# %% [markdown]
# #### Performance Analysis

# %%
from sklearn.metrics import classification_report, accuracy_score
from sklearn.metrics import ConfusionMatrixDisplay

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_mlp)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
print(classification_report(y_test, y_pred_mlp))
# Out:
#                    precision    recall  f1-score   support
#
# Kirmizi_Pistachio       0.89      0.87      0.88       295
#    Siit_Pistachio       0.87      0.89      0.88       294
#
#          accuracy                           0.88       589
#         macro avg       0.88      0.88      0.88       589
#      weighted avg       0.88      0.88      0.88       589

# %%
print('Accuracy score:', accuracy_score(y_test, y_pred_mlp)*100)
# Out:
# Accuracy score: 88.11544991511036

# %% [markdown]
# ### Accuracy Score of all the algorithms

# %%
print('Decision Tree Accuracy score:', accuracy_score(y_test, y_pred_dt)*100)
print('Random Forest Accuracy score:', accuracy_score(y_test, y_pred_rf)*100)
print('Logistic Regression Accuracy score:', accuracy_score(y_test, y_pred_lr)*100)
print('K-Nearest Neighbour Accuracy score:', accuracy_score(y_test, y_pred_knn)*100)
print('Gaussian Naive Bayes Accuracy score:', accuracy_score(y_test, y_pred_gnb)*100)
print('Support Vector Machines Accuracy score:', accuracy_score(y_test, y_pred_svc)*100)
print('Multi-Layer Perceptron Accuracy score:', accuracy_score(y_test, y_pred_mlp)*100)
# Out:
# Decision Tree Accuracy score: 85.22920203735144
# Random Forest Accuracy score: 89.64346349745331
# Logistic Regression Accuracy score: 88.45500848896435
# K-Nearest Neighbour Accuracy score: 91.00169779286928
# Gaussian Naive Bayes Accuracy score: 87.77589134125637
# Support Vector Machines Accuracy score: 88.96434634974533
# Multi-Layer Perceptron Accuracy score: 88.11544991511036

# %% [markdown]
# ### Deployment

# %%
# Serialization
import joblib

# %%
joblib.dump(grid, 'classifier.model')
# Out:
# ['classifier.model']

# %%
joblib.dump(scaler, 'scaler.model')
# Out:
# ['scaler.model']

# %%
x.columns
# Out:
# Index(['AREA', 'PERIMETER', 'MAJOR_AXIS', 'MINOR_AXIS', 'EQDIASQ',
#        'CONVEX_AREA', 'ASPECT_RATIO', 'ROUNDNESS', 'COMPACTNESS',
#        'SHAPEFACTOR_3'],
#       dtype='object')

# %% [markdown]
# ### Project GUI

# %%
from tkinter import *
import tkinter.messagebox
import numpy as np
import matplotlib.pyplot as plt

# %%
top = Tk()
top.title('Pistachio Categorization System')
top.geometry("1000x800")
top.resizable(0,0)

#Deserialization
classifier = joblib.load('classifier.model')
scaler = joblib.load('scaler.model')

def check():
    global a,b,c,d,e,f,g,h,i,j
    new = np.array([[a.get(), b.get(), c.get(), d.get(), e.get(), 
                     f.get(), g.get(), h.get(), i.get(), j.get()]])
    y_pred = classifier.predict(scaler.transform(new))
    if y_pred[0] == 'Kirmizi_Pistachio':
        tkinter.messagebox.showinfo('Result','Kirmizi Pistachio')
    elif y_pred[0] == 'Siit_Pistachio':
        tkinter.messagebox.showinfo('Result','Siit Pistachio')
    

a = DoubleVar()
b = DoubleVar()
c = DoubleVar()
d = DoubleVar()
e = DoubleVar()
f = DoubleVar()
g = DoubleVar()
h = DoubleVar()
i = DoubleVar()
j = DoubleVar()

Label(top, text='Pistachio Quality Detection System',
     font=('Ubuntu',25)).place(x=120,y=30)
Label(top, text='Area',
     font=('courier',16)).place(x=20,y=100)
Entry(top, textvariable=a, font=('courier',16)).place(x=280,y=100)
Label(top, text='Perimeter',
     font=('courier',16)).place(x=20,y=150)
Entry(top, textvariable=b, font=('courier',16)).place(x=280,y=150)
Label(top, text='Major Axis',
     font=('courier',16)).place(x=20,y=200)
Entry(top, textvariable=c, font=('courier',16)).place(x=280,y=200)
Label(top, text='Minor Axis',
     font=('courier',16)).place(x=20,y=250)
Entry(top, textvariable=d, font=('courier',16)).place(x=280,y=250)
Label(top, text='EQDIASQ',
     font=('courier',16)).place(x=20,y=300)
Entry(top, textvariable=e, font=('courier',16)).place(x=280,y=300)
Label(top, text='Convex Area',
     font=('courier',16)).place(x=20,y=350)
Entry(top, textvariable=f, font=('courier',16)).place(x=280,y=350)
Label(top, text='Aspect Ratio',
     font=('courier',16)).place(x=20,y=400)
Entry(top, textvariable=g, font=('courier',16)).place(x=280,y=400)
Label(top, text='Roundness',
     font=('courier',16)).place(x=20,y=450)
Entry(top, textvariable=h, font=('courier',16)).place(x=280,y=450)
Label(top, text='Compactness',
     font=('courier',16)).place(x=20,y=500)
Entry(top, textvariable=i, font=('courier',16)).place(x=280,y=500)
Label(top, text='Shape Factor',
     font=('courier',16)).place(x=20,y=550)
Entry(top, textvariable=j, font=('courier',16)).place(x=280,y=550)

Button(top, text = '--Check--',
      font=('courier',20,'bold'), command=check).place(x=700, y=300)

top.mainloop()
